# %% [markdown]
# # Librerias
# -----------------------------

# %%
# Librerias

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score

# %%
#Obtenemos los datos

x_train_with_outliers = pd.read_csv("../data/processed/x_train_sel_with_outliers.csv")
x_train_without_outliers = pd.read_csv("../data/processed/x_train_sel_without_outliers.csv")
x_test_with_outliers = pd.read_csv("../data/processed/x_test_sel_with_outliers.csv")
x_test_without_outliers = pd.read_csv("../data/processed/x_test_sel_without_outliers.csv")
y_train = pd.read_csv("../data/processed/y_train.csv")
y_test = pd.read_csv("../data/processed/y_test.csv")

# %%
#Creamos una funcion para entrenar el modelo.

def Training_model (x_train, x_test, y_target):
    model = RandomForestClassifier(random_state=42)
    model.fit(x_train, y_target)
    y_predict = model.predict(x_test)
    
    
    return y_predict

Training_model(x_train_with_outliers, x_test_with_outliers, y_train)
# Out:
# array([[390,   1],
#        [758,   0],
#        [158,   0],
#        [464,   0],
#        [517,   1],
#        [429,   1],
#        [ 90,   0],
#        [131,   1],
#        [260,   1],
#        [666,   1],
#        [557,   0],
#        [759,   1],
#        [547,   0],
#        [503,   1],
#        [158,   0],
#        [374,   0],
#        [554,   0],
#        [158,   0],
#        [260,   0],
#        [485,   1],
#        [557,   0],
#        [554,   0],
#        [583,   0],
#        [377,   0],
#        [ 25,   0],
#        [236,   1],
#        [615,   0],
#        [203,   0],
#        [ 73,   0],
#        [497,   0],
#        [335,   1],
#        [666,   1],
#        [132,   1],
#        [266,   1],
#        [129,   1],
#        [131,   1],
#        [260,   1],
#        [164,   0],
#        [509,   0],
#        [266,   1],
#        [ 82,   0],
#        [ 93,   0],
#        [719,   1],
#        [559,   0],
#        [601,   0],
#        [132,   0],
#        [540,   1],
#        [719,   0],
#        [278,   0],
#        [335,   1],
#        [514,   0],
#        [323,   1],
#        [388,   1],
#        [340,   0],
#        [713,   0],
#        [572,   0],
#        [495,   1],
#        [ 60,   0],
#        [198,   0],
#        [327,   1],
#        [  0,   1],
#        [758,   0],
#        [140,   0],
#        [ 82,   0],
#        [631,   0],
#        [485,   1],
#        [632,   0],
#        [178,   1],
#        [145,   0],
#        [235,   1],
#        [114,   1],
#        [559,   0],
#        [557,   0],
#        [631,   0],
#        [ 42,   0],
#        [141,   0],
#        [284,   0],
#        [ 35,   0],
#        [423,   0],
#        [481,   0],
#        [ 44,   1],
#        [311,   0],
#        [302,   0],
#        [177,   0],
#        [530,   0],
#        [ 56,   1],
#        [746,   1],
#        [326,   0],
#        [463,   0],
#        [373,   0],
#        [ 83,   0],
#        [705,   0],
#        [426,   0],
#        [664,   0],
#        [374,   0],
#        [417,   1],
#        [ 15,   1],
#        [637,   0],
#        [414,   1],
#        [176,   0],
#        [666,   1],
#        [273,   0],
#        [590,   1],
#        [689,   1],
#        [238,   1],
#        [318,   0],
#        [340,   0],
#        [696,   1],
#        [104,   0],
#        [443,   1],
#        [163,   0],
#        [500,   0],
#        [522,   0],
#        [ 24,   1],
#        [726,   0],
#        [255,   0],
#        [266,   1],
#        [256,   0],
#        [163,   0],
#        [522,   0],
#        [671,   0],
#        [311,   0],
#        [616,   0],
#        [353,   0],
#        [325,   0],
#        [298,   0],
#        [522,   0],
#        [152,   1],
#        [357,   1],
#        [ 43,   1],
#        [319,   1],
#        [424,   1],
#        [279,   0],
#        [578,   0],
#        [412,   1],
#        [329,   0],
#        [616,   0],
#        [ 24,   1],
#        [  0,   1],
#        [461,   0],
#        [632,   0],
#        [ 89,   0],
#        [478,   0],
#        [153,   0],
#        [253,   0],
#        [737,   0],
#        [ 82,   0],
#        [ 75,   0],
#        [116,   0],
#        [283,   1],
#        [173,   0],
#        [674,   0],
#        [320,   0],
#        [737,   0]])
